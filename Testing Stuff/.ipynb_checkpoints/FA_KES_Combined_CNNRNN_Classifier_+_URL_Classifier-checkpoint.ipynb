# %% [markdown]
# ##### CNN-RNN

# %%
import tensorflow as tf
import pandas as pd
import gensim
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, Flatten, MaxPooling1D, LSTM, Embedding, Input, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import multilabel_confusion_matrix
from numpy import unique
from tensorflow.keras import layers
from tensorflow.math import confusion_matrix

# %%
test = pd.read_csv("../Datasets/FA-KESDataset/FA-KES-Dataset.csv")
test.columns
test.head()
# Out:
#       unit_id                                      article_title  \
# 0  1914947530  Syria attack symptoms consistent with nerve ag...
# 1  1914947532  Homs governor says U.S. attack caused deaths b...
# 2  1914947533    Death toll from Aleppo bomb attack at least 112
# 3  1914947534        Aleppo bomb blast kills six Syrian state TV
# 4  1914947535  29 Syria Rebels Dead in Fighting for Key Alepp...
#
#                                      article_content source       date  \
# 0  Wed 05 Apr 2017 Syria attack symptoms consiste...    nna   4/5/2017
# 1  Fri 07 Apr 2017 at 0914 Homs governor says U.S...    nna   4/7/2017
# 2  Sun 16 Apr 2017 Death toll from Aleppo bomb at...    nna  4/16/2017
# 3  Wed 19 Apr 2017 Aleppo bomb blast kills six Sy...    nna  4/19/2017
# 4  Sun 10 Jul 2016 29 Syria Rebels Dead in Fighti...    nna  7/10/2016
#
#   location  labels                                                URL
# 0    idlib       0          http://nna-leb.gov.lb/en/show-news/77705/
# 1     homs       0  http://nna-leb.gov.lb/en/show-news/77731/nna-l...
# 2   aleppo       0  http://nna-leb.gov.lb/en/show-news/29474/nna-l...
# 3   aleppo       0  http://nna-leb.gov.lb/en/show-news/78274/nna-l...
# 4   aleppo       0  http://nna-leb.gov.lb/en/show-news/65189/nna-l...

# %%
test['labels'].value_counts()
# Out:
# 1    426
# 0    378
# Name: labels, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='labels', data=test)
# Out:
# <AxesSubplot:xlabel='labels', ylabel='count'>

# %%
test['article_content'] = test['article_content'].apply(lambda x: str(x).lower())

# %%
test = test[['article_content', 'labels']]

# %%
test['labels'] = test['labels'].astype(float)

# %%
# !pip install spacy==2.2.3
# !python -m spacy download en_core_web_sm
# !pip install beautifulsoup4==4.9.1
# !pip install textblob==0.15.3
# !pip install git+https://github.com/laxmimerit/preprocess_kgptalkie.git --upgrade --force-reinstall
# Out:
# Requirement already satisfied: spacy==2.2.3 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (2.2.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy==2.2.3) (0.9.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy==2.2.3) (1.0.6)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy==2.2.3) (1.1.3)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy==2.2.3) (1.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy==2.2.3) (2.0.6)
# Requirement already satisfied: setuptools in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy==2.2.3) (58.0.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy==2.2.3) (2.27.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy==2.2.3) (1.19.2)
# Requirement already satisfied: thinc<7.4.0,>=7.3.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy==2.2.3) (7.3.1)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy==2.2.3) (1.0.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy==2.2.3) (3.0.6)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy==2.2.3) (0.4.1)
# Requirement already satisfied: importlib-metadata>=0.20 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy==2.2.3) (4.8.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy==2.2.3) (4.0.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy==2.2.3) (3.6.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.3) (1.26.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from thinc<7.4.0,>=7.3.0->spacy==2.2.3) (4.62.3)
# Requirement already satisfied: colorama in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from tqdm<5.0.0,>=4.10.0->thinc<7.4.0,>=7.3.0->spacy==2.2.3) (0.4.4)
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
# Requirement already satisfied: spacy>=2.2.2 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from en_core_web_sm==2.2.5) (2.2.3)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: setuptools in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (58.0.4)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.19.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.27.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.9.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: thinc<7.4.0,>=7.3.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.3.1)
# Requirement already satisfied: importlib-metadata>=0.20 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.8.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from thinc<7.4.0,>=7.3.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.62.3)
# Requirement already satisfied: colorama in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from tqdm<5.0.0,>=4.10.0->thinc<7.4.0,>=7.3.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.4)
# [+] Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# Requirement already satisfied: beautifulsoup4==4.9.1 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from beautifulsoup4==4.9.1) (2.3.1)
# Requirement already satisfied: textblob==0.15.3 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from textblob==0.15.3) (3.6.7)
# Requirement already satisfied: tqdm in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from nltk>=3.1->textblob==0.15.3) (4.62.3)
# Requirement already satisfied: click in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from nltk>=3.1->textblob==0.15.3) (8.0.3)
# Requirement already satisfied: joblib in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from nltk>=3.1->textblob==0.15.3) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from nltk>=3.1->textblob==0.15.3) (2021.11.10)
# Requirement already satisfied: colorama in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from click->nltk>=3.1->textblob==0.15.3) (0.4.4)
# Requirement already satisfied: importlib-metadata in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from click->nltk>=3.1->textblob==0.15.3) (4.8.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from importlib-metadata->click->nltk>=3.1->textblob==0.15.3) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from importlib-metadata->click->nltk>=3.1->textblob==0.15.3) (4.0.1)
# Collecting git+https://github.com/laxmimerit/preprocess_kgptalkie.git
#   Cloning https://github.com/laxmimerit/preprocess_kgptalkie.git to c:\users\bliu0\appdata\local\temp\pip-req-build-trnohvs6
#   Resolved https://github.com/laxmimerit/preprocess_kgptalkie.git to commit 9ca68d37027af9f6a30d54640347ce3b2e2694b3
# Building wheels for collected packages: preprocess-kgptalkie
#   Building wheel for preprocess-kgptalkie (setup.py): started
#   Building wheel for preprocess-kgptalkie (setup.py): finished with status 'done'
#   Created wheel for preprocess-kgptalkie: filename=preprocess_kgptalkie-0.1.3-py3-none-any.whl size=7691 sha256=ffafa87fd57e7a332ea2511f2f0b68fe537baaf6dc6553a8bd4c8ec0a8457225
#   Stored in directory: C:\Users\bliu0\AppData\Local\Temp\pip-ephem-wheel-cache-uddcb7vw\wheels\cd\26\af\103cfac199bd773bfc95ed85a52fe9095e4d902ed9ac3b0c97
# Successfully built preprocess-kgptalkie
# Installing collected packages: preprocess-kgptalkie
#   Attempting uninstall: preprocess-kgptalkie
#     Found existing installation: preprocess-kgptalkie 0.1.3
#     Uninstalling preprocess-kgptalkie-0.1.3:
#       Successfully uninstalled preprocess-kgptalkie-0.1.3
# Successfully installed preprocess-kgptalkie-0.1.3
#   Running command git clone -q https://github.com/laxmimerit/preprocess_kgptalkie.git 'C:\Users\bliu0\AppData\Local\Temp\pip-req-build-trnohvs6'

# %%
import preprocess_kgptalkie as ps

# %%
test['article_content'] = test['article_content'].apply(lambda x: ps.remove_special_chars(x))

# %%
x = [d.split() for d in test['article_content'].tolist()]
y = test['labels'].values

# %%
pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (0.8.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from imbalanced-learn) (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from imbalanced-learn) (1.19.2)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from imbalanced-learn) (1.5.4)
# Requirement already satisfied: scikit-learn>=0.24 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from imbalanced-learn) (0.24.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from scikit-learn>=0.24->imbalanced-learn) (3.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
print(len(x))
# Out:
# 804

# %%
DIM = 400
w2v_model = gensim.models.Word2Vec(sentences=x, vector_size=DIM, window=10, min_count=1)

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(x)

# %%
x = tokenizer.texts_to_sequences(x)

# %%
plt.hist([len(a) for a in x], bins = 700)
plt.show()

# %%
nos = np.array([len(a) for a in x])
len(nos[nos>1000])
# Out:
# 4

# %%
maxlen = 100
x = tf.keras.preprocessing.sequence.pad_sequences(x, maxlen=maxlen)

# %%
vocab_size = len(tokenizer.word_index) + 1
vocab = tokenizer.word_index

# %%
def get_weight_matrix(model):
    weight_matrix = np.zeros((vocab_size, DIM))
    
    for word, i in vocab.items():
        try:
            weight_matrix[i] = model.wv[word]
        except:
            print("whatever")
        
    return weight_matrix

# %%
embedding_vectors = get_weight_matrix(w2v_model)

# %%
embedding_vectors.shape
# Out:
# (11008, 400)

# %%
maxlen
# Out:
# 100

# %%
model = Sequential()

model.add(Embedding(vocab_size, output_dim=DIM, weights=[embedding_vectors], input_length=maxlen, trainable = False))
model.add(Conv1D(128, 5, activation="relu"))
model.add(MaxPooling1D(pool_size=2, strides=2, padding="valid")) 
model.add(LSTM(32))
model.add(Dense(1, activation = 'sigmoid')) 
model.compile(loss = tf.keras.losses.BinaryCrossentropy(), 
    optimizer = "Adam",               
              metrics = ['accuracy', 'Recall', 'Precision', 'TrueNegatives', 'TruePositives', 'FalsePositives', 'FalseNegatives'])
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\bliu0\anaconda3\envs\tf\lib\site-packages\tensorflow_core\python\keras\initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\bliu0\anaconda3\envs\tf\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:OMP_NUM_THREADS is no longer used by the default Keras config. To configure the number of threads, use tf.config.threading APIs.
# WARNING:tensorflow:From C:\Users\bliu0\anaconda3\envs\tf\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 100, 400)          4403200
# _________________________________________________________________
# conv1d (Conv1D)              (None, 96, 128)           256128
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 48, 128)           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                20608
# _________________________________________________________________
# dense (Dense)                (None, 1)                 33
# =================================================================
# Total params: 4,679,969
# Trainable params: 276,769
# Non-trainable params: 4,403,200
# _________________________________________________________________

# %%
len(x)
# Out:
# 804

# %%
CNNRNNX_train, CNNRNNX_test, CNNRNNy_train, CNNRNNy_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
CNNRNNy_train = np.array(CNNRNNy_train)
CNNRNNy_test = np.array(CNNRNNy_test)

# %%
model.fit(CNNRNNX_train, CNNRNNy_train, epochs=100, batch_size=64)
# Out:
# Train on 643 samples
# Epoch 1/100
# 643/643 [==============================] - 1s 909us/sample - loss: 0.0672 - acc: 0.9518 - recall: 0.9496 - precision: 0.9581 - true_negatives: 292.0000 - true_positives: 320.0000 - false_positives: 14.0000 - false_negatives: 17.0000
# Epoch 2/100
# 643/643 [==============================] - 1s 920us/sample - loss: 0.0643 - acc: 0.9642 - recall: 0.9763 - precision: 0.9564 - true_negatives: 291.0000 - true_positives: 329.0000 - false_positives: 15.0000 - false_negatives: 8.0000
# Epoch 3/100
# 643/643 [==============================] - 1s 904us/sample - loss: 0.0807 - acc: 0.9611 - recall: 0.9436 - precision: 0.9815 - true_negatives: 300.0000 - true_positives: 318.0000 - false_positives: 6.0000 - false_negatives: 19.0000
# Epoch 4/100
# 643/643 [==============================] - 1s 898us/sample - loss: 0.0829 - acc: 0.9627 - recall: 0.9525 - precision: 0.9757 - true_negatives: 298.0000 - true_positives: 321.0000 - false_positives: 8.0000 - false_negatives: 16.0000
# Epoch 5/100
# 643/643 [==============================] - 1s 904us/sample - loss: 0.1061 - acc: 0.9565 - recall: 0.9407 - precision: 0.9754 - true_negatives: 298.0000 - true_positives: 317.0000 - false_positives: 8.0000 - false_negatives: 20.0000
# Epoch 6/100
# 643/643 [==============================] - 1s 900us/sample - loss: 0.1394 - acc: 0.9487 - recall: 0.9466 - precision: 0.9551 - true_negatives: 291.0000 - true_positives: 319.0000 - false_positives: 15.0000 - false_negatives: 18.0000
# Epoch 7/100
# 643/643 [==============================] - 1s 906us/sample - loss: 0.1163 - acc: 0.9596 - recall: 0.9555 - precision: 0.9670 - true_negatives: 295.0000 - true_positives: 322.0000 - false_positives: 11.0000 - false_negatives: 15.0000
# Epoch 8/100
# 643/643 [==============================] - 1s 898us/sample - loss: 0.0971 - acc: 0.9627 - recall: 0.9614 - precision: 0.9672 - true_negatives: 295.0000 - true_positives: 324.0000 - false_positives: 11.0000 - false_negatives: 13.0000
# Epoch 9/100
# 643/643 [==============================] - 1s 902us/sample - loss: 0.0853 - acc: 0.9596 - recall: 0.9436 - precision: 0.9785 - true_negatives: 299.0000 - true_positives: 318.0000 - false_positives: 7.0000 - false_negatives: 19.0000
# Epoch 10/100
# 643/643 [==============================] - 1s 899us/sample - loss: 0.0765 - acc: 0.9611 - recall: 0.9585 - precision: 0.9671 - true_negatives: 295.0000 - true_positives: 323.0000 - false_positives: 11.0000 - false_negatives: 14.0000
# Epoch 11/100
# 643/643 [==============================] - 1s 910us/sample - loss: 0.0752 - acc: 0.9565 - recall: 0.9347 - precision: 0.9813 - true_negatives: 300.0000 - true_positives: 315.0000 - false_positives: 6.0000 - false_negatives: 22.0000
# Epoch 12/100
# 643/643 [==============================] - 1s 905us/sample - loss: 0.0677 - acc: 0.9549 - recall: 0.9407 - precision: 0.9724 - true_negatives: 297.0000 - true_positives: 317.0000 - false_positives: 9.0000 - false_negatives: 20.0000
# Epoch 13/100
# 643/643 [==============================] - 1s 897us/sample - loss: 0.0740 - acc: 0.9627 - recall: 0.9703 - precision: 0.9589 - true_negatives: 292.0000 - true_positives: 327.0000 - false_positives: 14.0000 - false_negatives: 10.0000
# Epoch 14/100
# 643/643 [==============================] - 1s 896us/sample - loss: 0.0761 - acc: 0.9642 - recall: 0.9644 - precision: 0.9673 - true_negatives: 295.0000 - true_positives: 325.0000 - false_positives: 11.0000 - false_negatives: 12.0000
# Epoch 15/100
# 643/643 [==============================] - 1s 899us/sample - loss: 0.1105 - acc: 0.9471 - recall: 0.9169 - precision: 0.9810 - true_negatives: 300.0000 - true_positives: 309.0000 - false_positives: 6.0000 - false_negatives: 28.0000
# Epoch 16/100
# 643/643 [==============================] - 1s 902us/sample - loss: 0.1095 - acc: 0.9471 - recall: 0.9555 - precision: 0.9443 - true_negatives: 287.0000 - true_positives: 322.0000 - false_positives: 19.0000 - false_negatives: 15.0000
# Epoch 17/100
# 643/643 [==============================] - 1s 900us/sample - loss: 0.1040 - acc: 0.9456 - recall: 0.9228 - precision: 0.9719 - true_negatives: 297.0000 - true_positives: 311.0000 - false_positives: 9.0000 - false_negatives: 26.0000
# Epoch 18/100
# 643/643 [==============================] - 1s 898us/sample - loss: 0.1577 - acc: 0.9222 - recall: 0.9496 - precision: 0.9065 - true_negatives: 273.0000 - true_positives: 320.0000 - false_positives: 33.0000 - false_negatives: 17.0000
# Epoch 19/100
# 643/643 [==============================] - 1s 896us/sample - loss: 0.1487 - acc: 0.9347 - recall: 0.9228 - precision: 0.9511 - true_negatives: 290.0000 - true_positives: 311.0000 - false_positives: 16.0000 - false_negatives: 26.0000
# Epoch 20/100
# 643/643 [==============================] - 1s 902us/sample - loss: 0.1177 - acc: 0.9487 - recall: 0.9644 - precision: 0.9393 - true_negatives: 285.0000 - true_positives: 325.0000 - false_positives: 21.0000 - false_negatives: 12.0000
# Epoch 21/100
# 643/643 [==============================] - 1s 898us/sample - loss: 0.1249 - acc: 0.9362 - recall: 0.9288 - precision: 0.9485 - true_negatives: 289.0000 - true_positives: 313.0000 - false_positives: 17.0000 - false_negatives: 24.0000
# Epoch 22/100
# 643/643 [==============================] - 1s 899us/sample - loss: 0.1126 - acc: 0.9440 - recall: 0.9466 - precision: 0.9466 - true_negatives: 288.0000 - true_positives: 319.0000 - false_positives: 18.0000 - false_negatives: 18.0000
# Epoch 23/100
# 643/643 [==============================] - 1s 905us/sample - loss: 0.1370 - acc: 0.9393 - recall: 0.9228 - precision: 0.9599 - true_negatives: 293.0000 - true_positives: 311.0000 - false_positives: 13.0000 - false_negatives: 26.0000
# Epoch 24/100
# 643/643 [==============================] - 1s 898us/sample - loss: 0.2768 - acc: 0.9020 - recall: 0.9021 - precision: 0.9102 - true_negatives: 276.0000 - true_positives: 304.0000 - false_positives: 30.0000 - false_negatives: 33.0000
# Epoch 25/100
# 643/643 [==============================] - 1s 899us/sample - loss: 0.2471 - acc: 0.9020 - recall: 0.8991 - precision: 0.9127 - true_negatives: 277.0000 - true_positives: 303.0000 - false_positives: 29.0000 - false_negatives: 34.0000
# Epoch 26/100
# 643/643 [==============================] - 1s 903us/sample - loss: 0.1513 - acc: 0.9285 - recall: 0.9258 - precision: 0.9369 - true_negatives: 285.0000 - true_positives: 312.0000 - false_positives: 21.0000 - false_negatives: 25.0000
# Epoch 27/100
# 643/643 [==============================] - 1s 918us/sample - loss: 0.1291 - acc: 0.9440 - recall: 0.9436 - precision: 0.9493 - true_negatives: 289.0000 - true_positives: 318.0000 - false_positives: 17.0000 - false_negatives: 19.0000
# Epoch 28/100
# 643/643 [==============================] - 1s 898us/sample - loss: 0.1120 - acc: 0.9471 - recall: 0.9436 - precision: 0.9550 - true_negatives: 291.0000 - true_positives: 318.0000 - false_positives: 15.0000 - false_negatives: 19.0000
# Epoch 29/100
# 643/643 [==============================] - 1s 909us/sample - loss: 0.0968 - acc: 0.9549 - recall: 0.9407 - precision: 0.9724 - true_negatives: 297.0000 - true_positives: 317.0000 - false_positives: 9.0000 - false_negatives: 20.0000
# Epoch 30/100
# 643/643 [==============================] - 1s 909us/sample - loss: 0.0901 - acc: 0.9518 - recall: 0.9466 - precision: 0.9608 - true_negatives: 293.0000 - true_positives: 319.0000 - false_positives: 13.0000 - false_negatives: 18.0000
# Epoch 31/100
# 643/643 [==============================] - 1s 906us/sample - loss: 0.0835 - acc: 0.9611 - recall: 0.9614 - precision: 0.9643 - true_negatives: 294.0000 - true_positives: 324.0000 - false_positives: 12.0000 - false_negatives: 13.0000
# Epoch 32/100
# 643/643 [==============================] - 1s 909us/sample - loss: 0.0808 - acc: 0.9611 - recall: 0.9525 - precision: 0.9727 - true_negatives: 297.0000 - true_positives: 321.0000 - false_positives: 9.0000 - false_negatives: 16.0000
# Epoch 33/100
# 643/643 [==============================] - 1s 896us/sample - loss: 0.0754 - acc: 0.9611 - recall: 0.9525 - precision: 0.9727 - true_negatives: 297.0000 - true_positives: 321.0000 - false_positives: 9.0000 - false_negatives: 16.0000
# Epoch 34/100
# 643/643 [==============================] - 1s 900us/sample - loss: 0.0727 - acc: 0.9565 - recall: 0.9555 - precision: 0.9612 - true_negatives: 293.0000 - true_positives: 322.0000 - false_positives: 13.0000 - false_negatives: 15.0000
# Epoch 35/100
# 643/643 [==============================] - 1s 895us/sample - loss: 0.1004 - acc: 0.9549 - recall: 0.9377 - precision: 0.9753 - true_negatives: 298.0000 - true_positives: 316.0000 - false_positives: 8.0000 - false_negatives: 21.0000
# Epoch 36/100
# 643/643 [==============================] - 1s 897us/sample - loss: 0.0948 - acc: 0.9549 - recall: 0.9436 - precision: 0.9695 - true_negatives: 296.0000 - true_positives: 318.0000 - false_positives: 10.0000 - false_negatives: 19.0000
# Epoch 37/100
# 643/643 [==============================] - 1s 896us/sample - loss: 0.0814 - acc: 0.9596 - recall: 0.9763 - precision: 0.9481 - true_negatives: 288.0000 - true_positives: 329.0000 - false_positives: 18.0000 - false_negatives: 8.0000
# Epoch 38/100
# 643/643 [==============================] - 1s 908us/sample - loss: 0.0918 - acc: 0.9596 - recall: 0.9733 - precision: 0.9507 - true_negatives: 289.0000 - true_positives: 328.0000 - false_positives: 17.0000 - false_negatives: 9.0000
# Epoch 39/100
# 643/643 [==============================] - 1s 894us/sample - loss: 0.0915 - acc: 0.9533 - recall: 0.9555 - precision: 0.9555 - true_negatives: 291.0000 - true_positives: 322.0000 - false_positives: 15.0000 - false_negatives: 15.0000
# Epoch 40/100
# 643/643 [==============================] - 1s 899us/sample - loss: 0.0985 - acc: 0.9658 - recall: 0.9585 - precision: 0.9758 - true_negatives: 298.0000 - true_positives: 323.0000 - false_positives: 8.0000 - false_negatives: 14.0000
# Epoch 41/100
# 643/643 [==============================] - 1s 896us/sample - loss: 0.0913 - acc: 0.9611 - recall: 0.9555 - precision: 0.9699 - true_negatives: 296.0000 - true_positives: 322.0000 - false_positives: 10.0000 - false_negatives: 15.0000
# Epoch 42/100
# 643/643 [==============================] - 1s 900us/sample - loss: 0.0804 - acc: 0.9658 - recall: 0.9703 - precision: 0.9646 - true_negatives: 294.0000 - true_positives: 327.0000 - false_positives: 12.0000 - false_negatives: 10.0000
# Epoch 43/100
# 643/643 [==============================] - 1s 900us/sample - loss: 0.0750 - acc: 0.9642 - recall: 0.9585 - precision: 0.9729 - true_negatives: 297.0000 - true_positives: 323.0000 - false_positives: 9.0000 - false_negatives: 14.0000
# Epoch 44/100
# 643/643 [==============================] - 1s 895us/sample - loss: 0.0727 - acc: 0.9627 - recall: 0.9703 - precision: 0.9589 - true_negatives: 292.0000 - true_positives: 327.0000 - false_positives: 14.0000 - false_negatives: 10.0000
# Epoch 45/100
# 643/643 [==============================] - 1s 910us/sample - loss: 0.0708 - acc: 0.9627 - recall: 0.9674 - precision: 0.9617 - true_negatives: 293.0000 - true_positives: 326.0000 - false_positives: 13.0000 - false_negatives: 11.0000
# Epoch 46/100
# 643/643 [==============================] - 1s 901us/sample - loss: 0.0719 - acc: 0.9658 - recall: 0.9585 - precision: 0.9758 - true_negatives: 298.0000 - true_positives: 323.0000 - false_positives: 8.0000 - false_negatives: 14.0000
# Epoch 47/100
# 643/643 [==============================] - 1s 895us/sample - loss: 0.0692 - acc: 0.9673 - recall: 0.9644 - precision: 0.9731 - true_negatives: 297.0000 - true_positives: 325.0000 - false_positives: 9.0000 - false_negatives: 12.0000
# Epoch 48/100
# 643/643 [==============================] - 1s 898us/sample - loss: 0.0681 - acc: 0.9611 - recall: 0.9585 - precision: 0.9671 - true_negatives: 295.0000 - true_positives: 323.0000 - false_positives: 11.0000 - false_negatives: 14.0000
# Epoch 49/100
# 643/643 [==============================] - 1s 910us/sample - loss: 0.0650 - acc: 0.9596 - recall: 0.9644 - precision: 0.9587 - true_negatives: 292.0000 - true_positives: 325.0000 - false_positives: 14.0000 - false_negatives: 12.0000
# Epoch 50/100
# 643/643 [==============================] - 1s 900us/sample - loss: 0.1299 - acc: 0.9533 - recall: 0.9228 - precision: 0.9873 - true_negatives: 302.0000 - true_positives: 311.0000 - false_positives: 4.0000 - false_negatives: 26.0000
# Epoch 51/100
# 643/643 [==============================] - 1s 896us/sample - loss: 0.1609 - acc: 0.9362 - recall: 0.9585 - precision: 0.9229 - true_negatives: 279.0000 - true_positives: 323.0000 - false_positives: 27.0000 - false_negatives: 14.0000
# Epoch 52/100
# 643/643 [==============================] - 1s 894us/sample - loss: 0.1394 - acc: 0.9518 - recall: 0.9377 - precision: 0.9693 - true_negatives: 296.0000 - true_positives: 316.0000 - false_positives: 10.0000 - false_negatives: 21.0000
# Epoch 53/100
# 643/643 [==============================] - 1s 907us/sample - loss: 0.1161 - acc: 0.9533 - recall: 0.9318 - precision: 0.9782 - true_negatives: 299.0000 - true_positives: 314.0000 - false_positives: 7.0000 - false_negatives: 23.0000
# Epoch 54/100
# 643/643 [==============================] - 1s 894us/sample - loss: 0.0887 - acc: 0.9627 - recall: 0.9436 - precision: 0.9845 - true_negatives: 301.0000 - true_positives: 318.0000 - false_positives: 5.0000 - false_negatives: 19.0000
# Epoch 55/100
# 643/643 [==============================] - 1s 895us/sample - loss: 0.0817 - acc: 0.9596 - recall: 0.9436 - precision: 0.9785 - true_negatives: 299.0000 - true_positives: 318.0000 - false_positives: 7.0000 - false_negatives: 19.0000
# Epoch 56/100
# 643/643 [==============================] - 1s 895us/sample - loss: 0.0738 - acc: 0.9596 - recall: 0.9436 - precision: 0.9785 - true_negatives: 299.0000 - true_positives: 318.0000 - false_positives: 7.0000 - false_negatives: 19.0000
# Epoch 57/100
# 643/643 [==============================] - 1s 909us/sample - loss: 0.0718 - acc: 0.9580 - recall: 0.9614 - precision: 0.9586 - true_negatives: 292.0000 - true_positives: 324.0000 - false_positives: 14.0000 - false_negatives: 13.0000
# Epoch 58/100
# 643/643 [==============================] - 1s 897us/sample - loss: 0.0784 - acc: 0.9549 - recall: 0.9436 - precision: 0.9695 - true_negatives: 296.0000 - true_positives: 318.0000 - false_positives: 10.0000 - false_negatives: 19.0000
# Epoch 59/100
# 643/643 [==============================] - 1s 895us/sample - loss: 0.0726 - acc: 0.9596 - recall: 0.9466 - precision: 0.9755 - true_negatives: 298.0000 - true_positives: 319.0000 - false_positives: 8.0000 - false_negatives: 18.0000
# Epoch 60/100
# 643/643 [==============================] - 1s 903us/sample - loss: 0.0696 - acc: 0.9658 - recall: 0.9614 - precision: 0.9730 - true_negatives: 297.0000 - true_positives: 324.0000 - false_positives: 9.0000 - false_negatives: 13.0000
# Epoch 61/100
# 643/643 [==============================] - 1s 894us/sample - loss: 0.0703 - acc: 0.9549 - recall: 0.9525 - precision: 0.9611 - true_negatives: 293.0000 - true_positives: 321.0000 - false_positives: 13.0000 - false_negatives: 16.0000
# Epoch 62/100
# 643/643 [==============================] - 1s 895us/sample - loss: 0.1224 - acc: 0.9502 - recall: 0.9792 - precision: 0.9296 - true_negatives: 281.0000 - true_positives: 330.0000 - false_positives: 25.0000 - false_negatives: 7.0000
# Epoch 63/100
# 643/643 [==============================] - 1s 894us/sample - loss: 0.1155 - acc: 0.9440 - recall: 0.9288 - precision: 0.9631 - true_negatives: 294.0000 - true_positives: 313.0000 - false_positives: 12.0000 - false_negatives: 24.0000
# Epoch 64/100
# 643/643 [==============================] - 1s 903us/sample - loss: 0.0883 - acc: 0.9565 - recall: 0.9496 - precision: 0.9668 - true_negatives: 295.0000 - true_positives: 320.0000 - false_positives: 11.0000 - false_negatives: 17.0000
# Epoch 65/100
# 643/643 [==============================] - 1s 895us/sample - loss: 0.0801 - acc: 0.9580 - recall: 0.9614 - precision: 0.9586 - true_negatives: 292.0000 - true_positives: 324.0000 - false_positives: 14.0000 - false_negatives: 13.0000
# Epoch 66/100
# 643/643 [==============================] - 1s 895us/sample - loss: 0.0915 - acc: 0.9658 - recall: 0.9436 - precision: 0.9907 - true_negatives: 303.0000 - true_positives: 318.0000 - false_positives: 3.0000 - false_negatives: 19.0000
# Epoch 67/100
# 643/643 [==============================] - 1s 907us/sample - loss: 0.0963 - acc: 0.9565 - recall: 0.9555 - precision: 0.9612 - true_negatives: 293.0000 - true_positives: 322.0000 - false_positives: 13.0000 - false_negatives: 15.0000
# Epoch 68/100
# 643/643 [==============================] - 1s 902us/sample - loss: 0.0847 - acc: 0.9642 - recall: 0.9644 - precision: 0.9673 - true_negatives: 295.0000 - true_positives: 325.0000 - false_positives: 11.0000 - false_negatives: 12.0000
# Epoch 69/100
# 643/643 [==============================] - 1s 895us/sample - loss: 0.0762 - acc: 0.9627 - recall: 0.9733 - precision: 0.9563 - true_negatives: 291.0000 - true_positives: 328.0000 - false_positives: 15.0000 - false_negatives: 9.0000
# Epoch 70/100
# 643/643 [==============================] - 1s 895us/sample - loss: 0.0711 - acc: 0.9642 - recall: 0.9733 - precision: 0.9591 - true_negatives: 292.0000 - true_positives: 328.0000 - false_positives: 14.0000 - false_negatives: 9.0000
# Epoch 71/100
# 643/643 [==============================] - 1s 896us/sample - loss: 0.0648 - acc: 0.9658 - recall: 0.9644 - precision: 0.9701 - true_negatives: 296.0000 - true_positives: 325.0000 - false_positives: 10.0000 - false_negatives: 12.0000
# Epoch 72/100
# 643/643 [==============================] - 1s 897us/sample - loss: 0.0622 - acc: 0.9658 - recall: 0.9644 - precision: 0.9701 - true_negatives: 296.0000 - true_positives: 325.0000 - false_positives: 10.0000 - false_negatives: 12.0000
# Epoch 73/100
# 643/643 [==============================] - 1s 895us/sample - loss: 0.0618 - acc: 0.9627 - recall: 0.9585 - precision: 0.9700 - true_negatives: 296.0000 - true_positives: 323.0000 - false_positives: 10.0000 - false_negatives: 14.0000
# Epoch 74/100
# 643/643 [==============================] - 1s 896us/sample - loss: 0.0623 - acc: 0.9658 - recall: 0.9733 - precision: 0.9619 - true_negatives: 293.0000 - true_positives: 328.0000 - false_positives: 13.0000 - false_negatives: 9.0000
# Epoch 75/100
# 643/643 [==============================] - 1s 899us/sample - loss: 0.0699 - acc: 0.9658 - recall: 0.9733 - precision: 0.9619 - true_negatives: 293.0000 - true_positives: 328.0000 - false_positives: 13.0000 - false_negatives: 9.0000
# Epoch 76/100
# 643/643 [==============================] - 1s 896us/sample - loss: 0.0685 - acc: 0.9642 - recall: 0.9644 - precision: 0.9673 - true_negatives: 295.0000 - true_positives: 325.0000 - false_positives: 11.0000 - false_negatives: 12.0000
# Epoch 77/100
# 643/643 [==============================] - 1s 897us/sample - loss: 0.0738 - acc: 0.9627 - recall: 0.9881 - precision: 0.9433 - true_negatives: 286.0000 - true_positives: 333.0000 - false_positives: 20.0000 - false_negatives: 4.0000
# Epoch 78/100
# 643/643 [==============================] - 1s 917us/sample - loss: 0.0746 - acc: 0.9658 - recall: 0.9792 - precision: 0.9565 - true_negatives: 291.0000 - true_positives: 330.0000 - false_positives: 15.0000 - false_negatives: 7.0000
# Epoch 79/100
# 643/643 [==============================] - 1s 909us/sample - loss: 0.0708 - acc: 0.9673 - recall: 0.9585 - precision: 0.9788 - true_negatives: 299.0000 - true_positives: 323.0000 - false_positives: 7.0000 - false_negatives: 14.0000
# Epoch 80/100
# 643/643 [==============================] - 1s 896us/sample - loss: 0.0655 - acc: 0.9673 - recall: 0.9614 - precision: 0.9759 - true_negatives: 298.0000 - true_positives: 324.0000 - false_positives: 8.0000 - false_negatives: 13.0000
# Epoch 81/100
# 643/643 [==============================] - 1s 896us/sample - loss: 0.0641 - acc: 0.9658 - recall: 0.9674 - precision: 0.9674 - true_negatives: 295.0000 - true_positives: 326.0000 - false_positives: 11.0000 - false_negatives: 11.0000
# Epoch 82/100
# 643/643 [==============================] - 1s 897us/sample - loss: 0.0624 - acc: 0.9642 - recall: 0.9644 - precision: 0.9673 - true_negatives: 295.0000 - true_positives: 325.0000 - false_positives: 11.0000 - false_negatives: 12.0000
# Epoch 83/100
# 643/643 [==============================] - 1s 901us/sample - loss: 0.0603 - acc: 0.9673 - recall: 0.9585 - precision: 0.9788 - true_negatives: 299.0000 - true_positives: 323.0000 - false_positives: 7.0000 - false_negatives: 14.0000
# Epoch 84/100
# 643/643 [==============================] - 1s 907us/sample - loss: 0.0643 - acc: 0.9642 - recall: 0.9703 - precision: 0.9618 - true_negatives: 293.0000 - true_positives: 327.0000 - false_positives: 13.0000 - false_negatives: 10.0000
# Epoch 85/100
# 643/643 [==============================] - 1s 905us/sample - loss: 0.0732 - acc: 0.9658 - recall: 0.9644 - precision: 0.9701 - true_negatives: 296.0000 - true_positives: 325.0000 - false_positives: 10.0000 - false_negatives: 12.0000
# Epoch 86/100
# 643/643 [==============================] - 1s 900us/sample - loss: 0.0709 - acc: 0.9627 - recall: 0.9614 - precision: 0.9672 - true_negatives: 295.0000 - true_positives: 324.0000 - false_positives: 11.0000 - false_negatives: 13.0000
# Epoch 87/100
# 643/643 [==============================] - 1s 893us/sample - loss: 0.0656 - acc: 0.9627 - recall: 0.9614 - precision: 0.9672 - true_negatives: 295.0000 - true_positives: 324.0000 - false_positives: 11.0000 - false_negatives: 13.0000
# Epoch 88/100
# 643/643 [==============================] - 1s 893us/sample - loss: 0.0676 - acc: 0.9673 - recall: 0.9703 - precision: 0.9675 - true_negatives: 295.0000 - true_positives: 327.0000 - false_positives: 11.0000 - false_negatives: 10.0000
# Epoch 89/100
# 643/643 [==============================] - 1s 908us/sample - loss: 0.0685 - acc: 0.9673 - recall: 0.9733 - precision: 0.9647 - true_negatives: 294.0000 - true_positives: 328.0000 - false_positives: 12.0000 - false_negatives: 9.0000
# Epoch 90/100
# 643/643 [==============================] - 1s 901us/sample - loss: 0.0630 - acc: 0.9689 - recall: 0.9674 - precision: 0.9731 - true_negatives: 297.0000 - true_positives: 326.0000 - false_positives: 9.0000 - false_negatives: 11.0000
# Epoch 91/100
# 643/643 [==============================] - 1s 895us/sample - loss: 0.0615 - acc: 0.9673 - recall: 0.9674 - precision: 0.9702 - true_negatives: 296.0000 - true_positives: 326.0000 - false_positives: 10.0000 - false_negatives: 11.0000
# Epoch 92/100
# 643/643 [==============================] - 1s 894us/sample - loss: 0.0585 - acc: 0.9673 - recall: 0.9674 - precision: 0.9702 - true_negatives: 296.0000 - true_positives: 326.0000 - false_positives: 10.0000 - false_negatives: 11.0000
# Epoch 93/100
# 643/643 [==============================] - 1s 896us/sample - loss: 0.0650 - acc: 0.9642 - recall: 0.9555 - precision: 0.9758 - true_negatives: 298.0000 - true_positives: 322.0000 - false_positives: 8.0000 - false_negatives: 15.0000
# Epoch 94/100
# 643/643 [==============================] - 1s 904us/sample - loss: 0.0586 - acc: 0.9673 - recall: 0.9614 - precision: 0.9759 - true_negatives: 298.0000 - true_positives: 324.0000 - false_positives: 8.0000 - false_negatives: 13.0000
# Epoch 95/100
# 643/643 [==============================] - 1s 896us/sample - loss: 0.0585 - acc: 0.9673 - recall: 0.9763 - precision: 0.9620 - true_negatives: 293.0000 - true_positives: 329.0000 - false_positives: 13.0000 - false_negatives: 8.0000
# Epoch 96/100
# 643/643 [==============================] - 1s 911us/sample - loss: 0.0563 - acc: 0.9658 - recall: 0.9733 - precision: 0.9619 - true_negatives: 293.0000 - true_positives: 328.0000 - false_positives: 13.0000 - false_negatives: 9.0000
# Epoch 97/100
# 643/643 [==============================] - 1s 904us/sample - loss: 0.0553 - acc: 0.9611 - recall: 0.9614 - precision: 0.9643 - true_negatives: 294.0000 - true_positives: 324.0000 - false_positives: 12.0000 - false_negatives: 13.0000
# Epoch 98/100
# 643/643 [==============================] - 1s 923us/sample - loss: 0.0549 - acc: 0.9673 - recall: 0.9614 - precision: 0.9759 - true_negatives: 298.0000 - true_positives: 324.0000 - false_positives: 8.0000 - false_negatives: 13.0000
# Epoch 99/100
# 643/643 [==============================] - 1s 896us/sample - loss: 0.0551 - acc: 0.9658 - recall: 0.9614 - precision: 0.9730 - true_negatives: 297.0000 - true_positives: 324.0000 - false_positives: 9.0000 - false_negatives: 13.0000
# Epoch 100/100
# 643/643 [==============================] - 1s 894us/sample - loss: 0.0544 - acc: 0.9611 - recall: 0.9644 - precision: 0.9615 - true_negatives: 293.0000 - true_positives: 325.0000 - false_positives: 13.0000 - false_negatives: 12.0000

# %%
model.evaluate(CNNRNNX_test, CNNRNNy_test)
# Out:
# 161/161 [==============================] - 0s 1ms/sample - loss: 0.6931 - acc: 0.5528 - recall: 1.0000 - precision: 0.5528 - true_negatives: 0.0000e+00 - true_positives: 89.0000 - false_positives: 72.0000 - false_negatives: 0.0000e+00
# [0.6930855605172814, 0.55279505, 1.0, 0.55279505, 0.0, 89.0, 72.0, 0.0]

# %% [markdown]
# # URL Classifier

# %%
# !pip install whois
# !pip install pyquery
# !pip install tqdm
# !pip install interruptingcow
# !pip install requests
# Out:
# Requirement already satisfied: whois in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (0.9.13)
# Requirement already satisfied: pyquery in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (1.4.3)
# Requirement already satisfied: cssselect>0.7.9 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from pyquery) (1.1.0)
# Requirement already satisfied: lxml>=2.1 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from pyquery) (4.7.1)
# Requirement already satisfied: tqdm in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (4.62.3)
# Requirement already satisfied: colorama in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from tqdm) (0.4.4)
# Requirement already satisfied: interruptingcow in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (0.8)
# Requirement already satisfied: requests in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from requests) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from requests) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\bliu0\anaconda3\envs\tf\lib\site-packages (from requests) (1.26.7)

# %%
import requests
from interruptingcow import timeout
import whois
from datetime import datetime, timezone
import math
import pandas as pd
import numpy as np
from pyquery import PyQuery
from requests import get
import tensorflow as tf
import pandas as pd
import gensim
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, Flatten, MaxPooling1D, LSTM, Embedding, Input
from sklearn.model_selection import train_test_split
from sklearn.metrics import multilabel_confusion_matrix
from numpy import unique
from tensorflow.keras import layers
from tensorflow.math import confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
class UrlFeaturizer(object):
    def __init__(self, url):
        self.url = url
        self.domain = url.split('//')[-1].split('/')[0]
        self.today = datetime.now().replace(tzinfo=None)

        try:
            self.whois = whois.query(self.domain).__dict__
        except:
            self.whois = None

        try:
            self.response = get(self.url)
            self.pq = PyQuery(self.response.text)
        except:
            self.response = None
            self.pq = None

    ## URL string Features
    def entropy(self):
        string = self.url.strip()
        prob = [float(string.count(c)) / len(string) for c in dict.fromkeys(list(string))]
        entropy = sum([(p * math.log(p) / math.log(2.0)) for p in prob])
        return entropy

    def ip(self):
        string = self.url
        flag = False
        if ("." in string):
            elements_array = string.strip().split(".")
            if(len(elements_array) == 4):
                for i in elements_array:
                    if (i.isnumeric() and int(i)>=0 and int(i)<=255):
                        flag=True
                    else:
                        flag=False
                        break
        if flag:
            return 1 
        else:
            return 0

    def numDigits(self):
        digits = [i for i in self.url if i.isdigit()]
        return len(digits)

    def urlLength(self):
        return len(self.url)

    def numParameters(self):
        params = self.url.split('&')
        return len(params) - 1

    def numFragments(self):
        fragments = self.url.split('#')
        return len(fragments) - 1

    def numSubDomains(self):
        subdomains = self.url.split('http')[-1].split('//')[-1].split('/')
        return len(subdomains)-1

    def domainExtension(self):
        ext = self.url.split('.')[-1].split('/')[0]
        return ext

    ## URL domain features
    def hasHttp(self):
        return 'http:' in self.url

    def hasHttps(self):
        return 'https:' in self.url

    def daysSinceRegistration(self):
        if self.whois and self.whois['creation_date']:
            diff = self.today - self.whois['creation_date'].replace(tzinfo=None)
            diff = str(diff).split(' days')[0]
            return diff
        else:
            return 0

    def daysSinceExpiration(self):
        if self.whois and self.whois['expiration_date']:
            diff = self.whois['expiration_date'].replace(tzinfo=None) - self.today
            diff = str(diff).split(' days')[0]
            return diff
        else:
            return 0
    
     ## URL Page Features
    def bodyLength(self):
        if self.pq is not None:
            return len(self.pq('html').text()) if self.urlIsLive else 0
        else:
            return 0

    def numTitles(self):
        if self.pq is not None:
            titles = ['h{}'.format(i) for i in range(7)]
            titles = [self.pq(i).items() for i in titles]
            return len([item for s in titles for item in s])
        else:
            return 0

    def numImages(self):
        if self.pq is not None:
            return len([i for i in self.pq('img').items()])
        else:
            return 0

    def numLinks(self):
        if self.pq is not None:
            return len([i for i in self.pq('a').items()])
        else:
            return 0

    def scriptLength(self):
        if self.pq is not None:
            return len(self.pq('script').text())
        else:
            return 0

    def specialCharacters(self):
        if self.pq is not None:
            bodyText = self.pq('html').text()
            schars = [i for i in bodyText if not i.isdigit() and not i.isalpha()]
            return len(schars)
        else:
            return 0

    def scriptToSpecialCharsRatio(self):
        v = self.specialCharacters()
        if self.pq is not None and v!=0:
            sscr = self.scriptLength()/v
        else:
            sscr = 0
        return sscr

    def scriptTobodyRatio(self):
        v = self.bodyLength()
        if self.pq is not None and v!=0:
            sbr = self.scriptLength()/v
        else:
            sbr = 0
        return sbr

    def bodyToSpecialCharRatio(self):
        v = self.bodyLength()
        if self.pq is not None and v!=0:
            bscr = self.specialCharacters()/v
        else:
            bscr = 0
        return bscr

    def urlIsLive(self):
        return self.response == 200

    def run(self):
        data = {}
        data['entropy'] = self.entropy()
        data['numDigits'] = self.numDigits()
        data['urlLength'] = self.urlLength()
        data['numParams'] = self.numParameters()
        data['hasHttp'] = self.hasHttp()
        data['hasHttps'] = self.hasHttps()
        data['urlIsLive'] = self.urlIsLive()
        data['bodyLength'] = self.bodyLength()
        data['numTitles'] = self.numTitles()
        data['numImages'] = self.numImages()
        data['numLinks'] = self.numLinks()
        data['scriptLength'] = self.scriptLength()
        data['specialChars'] = self.specialCharacters()
        data['ext'] = self.domainExtension()
        data['dsr'] = self.daysSinceRegistration()
        data['dse'] = self.daysSinceExpiration()
        data['sscr'] = self.scriptToSpecialCharsRatio()
        data['sbr'] = self.scriptTobodyRatio()
        data['bscr'] = self.bodyToSpecialCharRatio()
        data['num_%20'] = self.url.count("%20")
        data['num_@'] = self.url.count("@")
        data['has_ip'] = self.ip()
    
        return data

# %%
data = pd.read_csv('../Datasets/FA-KESDataset/FA-KES-Dataset.csv', names = ['id', 'title', 'content', 'source', 'date', 'location', 'rating', 'url'])
data.head(5)
# Out:
#            id                                              title  \
# 0     unit_id                                      article_title
# 1  1914947530  Syria attack symptoms consistent with nerve ag...
# 2  1914947532  Homs governor says U.S. attack caused deaths b...
# 3  1914947533    Death toll from Aleppo bomb attack at least 112
# 4  1914947534        Aleppo bomb blast kills six Syrian state TV
#
#                                              content  source       date  \
# 0                                    article_content  source       date
# 1  Wed 05 Apr 2017 Syria attack symptoms consiste...     nna   4/5/2017
# 2  Fri 07 Apr 2017 at 0914 Homs governor says U.S...     nna   4/7/2017
# 3  Sun 16 Apr 2017 Death toll from Aleppo bomb at...     nna  4/16/2017
# 4  Wed 19 Apr 2017 Aleppo bomb blast kills six Sy...     nna  4/19/2017
#
#    location  rating                                                url
# 0  location  labels                                                URL
# 1     idlib       0          http://nna-leb.gov.lb/en/show-news/77705/
# 2      homs       0  http://nna-leb.gov.lb/en/show-news/77731/nna-l...
# 3    aleppo       0  http://nna-leb.gov.lb/en/show-news/29474/nna-l...
# 4    aleppo       0  http://nna-leb.gov.lb/en/show-news/78274/nna-l...

# %%
data = data.drop(columns = ["source", "date", "location", "title", "content", "id"])
data = data.drop(data.index[0])

data.head(5)
# Out:
#   rating                                                url
# 1      0          http://nna-leb.gov.lb/en/show-news/77705/
# 2      0  http://nna-leb.gov.lb/en/show-news/77731/nna-l...
# 3      0  http://nna-leb.gov.lb/en/show-news/29474/nna-l...
# 4      0  http://nna-leb.gov.lb/en/show-news/78274/nna-l...
# 5      0  http://nna-leb.gov.lb/en/show-news/65189/nna-l...

# %%
data['rating'].value_counts()
data['rating'] = data['rating'].astype(float)

# %%
data.head(5)
# Out:
#    rating                                                url
# 1     0.0          http://nna-leb.gov.lb/en/show-news/77705/
# 2     0.0  http://nna-leb.gov.lb/en/show-news/77731/nna-l...
# 3     0.0  http://nna-leb.gov.lb/en/show-news/29474/nna-l...
# 4     0.0  http://nna-leb.gov.lb/en/show-news/78274/nna-l...
# 5     0.0  http://nna-leb.gov.lb/en/show-news/65189/nna-l...

# %%
features_list = []
for idx, row in data.iterrows():
  print(idx)
  url_string = row['url']
  rating = row['rating']
  features = UrlFeaturizer(url_string).run()
  features['rating'] = rating
  features_list.append(features)

df = pd.DataFrame(features_list)
# Out:
# 1
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 2
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 3
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 4
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 5
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 6
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 7
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 8
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 9
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 10
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 11
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 12
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 13
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 14
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 15
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 16
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 17
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 18
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 19
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 20
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 21
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 22
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 23
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 24
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 25
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 26
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 27
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 28
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 29
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 30
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 31
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 32
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 33
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 34
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 35
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 36
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 37
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 38
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 39
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 40
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 41
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 42
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 43
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 44
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 45
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 46
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 47
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 48
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 49
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 50
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 51
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 52
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 53
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 54
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 55
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 56
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 57
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 58
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 59
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 60
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 61
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 62
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 63
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 64
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 65
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 66
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 67
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 68
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 69
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 70
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 71
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 72
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 73
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 74
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 75
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 76
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 77
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 78
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 79
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 80
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 81
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 82
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 83
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 84
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 85
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 86
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 87
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 88
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 89
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 90
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 91
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 92
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 93
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 94
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 95
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 96
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 97
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 98
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 99
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 100
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 101
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 102
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 103
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 104
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 105
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 106
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 107
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 108
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 109
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 110
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 111
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 112
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 113
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 114
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 115
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 116
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 117
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 118
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 119
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 120
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 121
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 122
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 123
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 124
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 125
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 126
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 127
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 128
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 129
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 130
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 131
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 132
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 133
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 134
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 135
# downloading dependencies
# copy \\live.sysinternals.com\tools\whois.exe C:\Users\bliu0\OneDrive\Documents\GitHub\brianhelenfakenews\Testing Stuff
# 136
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 137
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 138
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 139
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 140
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 141
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 142
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 143
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 144
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 145
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 146
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 147
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 148
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 149
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 150
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 151
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 152
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 153
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 154
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 155
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 156
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 157
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 158
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 159
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 160
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 161
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 162
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 163
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 164
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 165
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 166
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 167
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 168
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 169
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 170
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 171
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 172
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 173
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 174
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 175
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 176
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 177
# Unknown TLD: .eg
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 178
# Unknown TLD: .eg
# ...
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 778
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 779
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 780
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 781
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 782
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 783
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 784
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 785
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 786
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 787
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 788
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 789
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 790
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 791
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 792
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 793
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 794
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 795
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 796
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 797
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 798
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 799
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 800
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 801
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 802
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 803
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za 804
# Unknown TLD: .lb
# Valid TLDs: .ac_uk .am .amsterdam .ar .at .au .bank .be .biz .br .by .ca .cc .cl .club .cn .co .co_il .co_jp .com .com_au .com_tr .cr .cz .de .download .edu .education .eu .fi .fm .fr .frl .game .global_ .hk .id_ .ie .im .in_ .info .ink .io .ir .is_ .it .jp .kr .kz .link .lt .lv .me .mobi .mu .mx .name .net .ninja .nl .nu .nyc .nz .online .org .pe .pharmacy .pl .press .pro .pt .pub .pw .rest .ru .ru_rf .rw .sale .se .security .sh .site .space .store .tech .tel .theatre .tickets .trade .tv .ua .uk .us .uz .video .website .wiki .work .xyz .za

# %%
df
# Out:
#       entropy  numDigits  urlLength  numParams  hasHttp  hasHttps  urlIsLive  \
# 0   -4.113173          5         41          0     True     False      False
# 1   -4.055393          5         73          0     True     False      False
# 2   -4.171736          5         55          0     True     False      False
# 3   -4.126561          5         58          0     True     False      False
# 4   -4.096221          5         73          0     True     False      False
# ..        ...        ...        ...        ...      ...       ...        ...
# 799 -4.469354          6         59          0     True     False      False
# 800 -4.469354          6         59          0     True     False      False
# 801 -4.503252          6         59          0     True     False      False
# 802 -4.537150          6         59          0     True     False      False
# 803 -4.371087          6         37          0    False      True      False
#
#      bodyLength  numTitles  numImages  ...            ext  dsr  dse      sscr  \
# 0          4915          5          0  ...             lb    0    0  2.719831
# 1          5027          5          0  ...             lb    0    0  2.742599
# 2          4963          5          0  ...             lb    0    0  2.734950
# 3          4975          5          0  ...             lb    0    0  2.715467
# 4          5033          5          0  ...             lb    0    0  2.747117
# ..          ...        ...        ...  ...            ...  ...  ...       ...
# 799        2648          2          3  ...  php?id=283853    0    0  1.394649
# 800        1919          2          3  ...  php?id=282445    0    0  1.837004
# 801        2612          2          3  ...  php?id=280817    0    0  1.455497
# 802        2691          2          3  ...  php?id=280641    0    0  1.383085
# 803       21966         17         31  ...             lb    0    0  2.146242
#
#           sbr      bscr  num_%20  num_@  has_ip  rating
# 0    0.655748  0.241099        0      0       0     0.0
# 1    0.663418  0.241894        0      0       0     0.0
# 2    0.659077  0.240983        0      0       0     0.0
# 3    0.659899  0.243015        0      0       0     0.0
# 4    0.662627  0.241208        0      0       0     0.0
# ..        ...       ...      ...    ...     ...     ...
# 799  0.314955  0.225831        0      0       0     1.0
# 800  0.434601  0.236582        0      0       0     1.0
# 801  0.319296  0.219372        0      0       0     0.0
# 802  0.309922  0.224080        0      0       0     1.0
# 803  0.503096  0.234408        0      0       0     1.0
#
# [804 rows x 23 columns]

# %%
df.replace(True,1,inplace = True)    
df.replace(False,0,inplace = True)

df.ext = pd.Categorical(df.ext).codes
print(df.ext.head(5))

y = df['rating'] 
encoder = LabelEncoder()    
encoder.fit(y)    
Y = encoder.transform(y)  
scaler = MinMaxScaler(feature_range=(0, 1))    

df = df.drop(columns = ['rating'])

X = pd.DataFrame(scaler.fit_transform(df))
# Out:
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4
# Name: ext, dtype: int8

# %%
X
# Out:
#            0         1         2    3    4    5    6         7         8   \
# 0    0.698318  0.238095  0.103448  0.0  1.0  0.0  0.0  0.013206  0.096154
# 1    0.746095  0.238095  0.324138  0.0  1.0  0.0  0.0  0.013507  0.096154
# 2    0.649893  0.238095  0.200000  0.0  1.0  0.0  0.0  0.013335  0.096154
# 3    0.687248  0.238095  0.220690  0.0  1.0  0.0  0.0  0.013367  0.096154
# 4    0.712335  0.238095  0.324138  0.0  1.0  0.0  0.0  0.013523  0.096154
# ..        ...       ...       ...  ...  ...  ...  ...       ...       ...
# 799  0.403799  0.285714  0.227586  0.0  1.0  0.0  0.0  0.007115  0.038462
# 800  0.403799  0.285714  0.227586  0.0  1.0  0.0  0.0  0.005156  0.038462
# 801  0.375769  0.285714  0.227586  0.0  1.0  0.0  0.0  0.007018  0.038462
# 802  0.347739  0.285714  0.227586  0.0  1.0  0.0  0.0  0.007230  0.038462
# 803  0.485053  0.285714  0.075862  0.0  0.0  1.0  0.0  0.059018  0.326923
#
#            9   ...        12        13   14   15        16        17  \
# 0    0.000000  ...  0.010808  0.038835  0.0  0.0  0.799469  0.660194
# 1    0.000000  ...  0.011090  0.038835  0.0  0.0  0.806161  0.667916
# 2    0.000000  ...  0.010908  0.038835  0.0  0.0  0.803913  0.663546
# 3    0.000000  ...  0.011026  0.038835  0.0  0.0  0.798186  0.664374
# 4    0.000000  ...  0.011072  0.038835  0.0  0.0  0.807489  0.667119
# ..        ...  ...       ...       ...  ...  ...       ...       ...
# 799  0.046154  ...  0.005454  0.980583  0.0  0.0  0.409944  0.317090
# 800  0.046154  ...  0.004141  0.970874  0.0  0.0  0.539970  0.437548
# 801  0.046154  ...  0.005226  0.961165  0.0  0.0  0.427830  0.321460
# 802  0.046154  ...  0.005500  0.951456  0.0  0.0  0.406545  0.312023
# 803  0.476923  ...  0.046961  0.038835  0.0  0.0  0.630868  0.506507
#
#            18   19   20   21
# 0    0.760501  0.0  0.0  0.0
# 1    0.763009  0.0  0.0  0.0
# 2    0.760137  0.0  0.0  0.0
# 3    0.766546  0.0  0.0  0.0
# 4    0.760846  0.0  0.0  0.0
# ..        ...  ...  ...  ...
# 799  0.712342  0.0  0.0  0.0
# 800  0.746253  0.0  0.0  0.0
# 801  0.691969  0.0  0.0  0.0
# 802  0.706820  0.0  0.0  0.0
# 803  0.739396  0.0  0.0  0.0
#
# [804 rows x 22 columns]

# %%
len(Y)
# Out:
# 804

# %%
URLX_train, URLX_test, URLy_train, URLy_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from tensorflow.keras.layers import InputLayer

model2 = Sequential()    
model2.add(InputLayer(22))
model2.add(Dense(256, input_dim = 22 , activation = 'relu'))    
model2.add(Dense(128, activation = 'relu'))    
model2.add(Dense(64, activation = 'relu'))    
model2.add(Dense(32, activation = 'relu'))    
model2.add(Dense(16, activation = 'relu'))    
model2.add(Dense(1, activation = 'sigmoid'))
model2.compile(loss = 'binary_crossentropy' ,optimizer='adam' , metrics = ['accuracy', 'Recall', 'Precision', 'TrueNegatives', 'TruePositives', 'FalsePositives', 'FalseNegatives'] )

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               5888
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_5 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 49,665
# Trainable params: 49,665
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.fit(URLX_train, URLy_train, epochs = 100)
# Out:
# Train on 643 samples
# Epoch 1/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6192 - acc: 0.6159 - recall_2: 0.6855 - precision_2: 0.6210 - true_negatives_2: 165.0000 - true_positives_2: 231.0000 - false_positives_2: 141.0000 - false_negatives_2: 106.0000
# Epoch 2/100
# 643/643 [==============================] - 0s 91us/sample - loss: 0.6205 - acc: 0.6190 - recall_2: 0.6588 - precision_2: 0.6307 - true_negatives_2: 176.0000 - true_positives_2: 222.0000 - false_positives_2: 130.0000 - false_negatives_2: 115.0000
# Epoch 3/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.6246 - acc: 0.6299 - recall_2: 0.6499 - precision_2: 0.6460 - true_negatives_2: 186.0000 - true_positives_2: 219.0000 - false_positives_2: 120.0000 - false_negatives_2: 118.0000
# Epoch 4/100
# 643/643 [==============================] - 0s 90us/sample - loss: 0.6358 - acc: 0.6081 - recall_2: 0.5964 - precision_2: 0.6341 - true_negatives_2: 190.0000 - true_positives_2: 201.0000 - false_positives_2: 116.0000 - false_negatives_2: 136.0000
# Epoch 5/100
# 643/643 [==============================] - 0s 101us/sample - loss: 0.6161 - acc: 0.6065 - recall_2: 0.5252 - precision_2: 0.6556 - true_negatives_2: 213.0000 - true_positives_2: 177.0000 - false_positives_2: 93.0000 - false_negatives_2: 160.0000
# Epoch 6/100
# 643/643 [==============================] - 0s 100us/sample - loss: 0.6249 - acc: 0.6112 - recall_2: 0.5519 - precision_2: 0.6526 - true_negatives_2: 207.0000 - true_positives_2: 186.0000 - false_positives_2: 99.0000 - false_negatives_2: 151.0000
# Epoch 7/100
# 643/643 [==============================] - 0s 99us/sample - loss: 0.6233 - acc: 0.6267 - recall_2: 0.6973 - precision_2: 0.6300 - true_negatives_2: 168.0000 - true_positives_2: 235.0000 - false_positives_2: 138.0000 - false_negatives_2: 102.0000
# Epoch 8/100
# 643/643 [==============================] - 0s 101us/sample - loss: 0.6203 - acc: 0.6314 - recall_2: 0.6973 - precision_2: 0.6351 - true_negatives_2: 171.0000 - true_positives_2: 235.0000 - false_positives_2: 135.0000 - false_negatives_2: 102.0000
# Epoch 9/100
# 643/643 [==============================] - 0s 109us/sample - loss: 0.6150 - acc: 0.6267 - recall_2: 0.6647 - precision_2: 0.6382 - true_negatives_2: 179.0000 - true_positives_2: 224.0000 - false_positives_2: 127.0000 - false_negatives_2: 113.0000
# Epoch 10/100
# 643/643 [==============================] - 0s 94us/sample - loss: 0.6181 - acc: 0.6376 - recall_2: 0.6884 - precision_2: 0.6444 - true_negatives_2: 178.0000 - true_positives_2: 232.0000 - false_positives_2: 128.0000 - false_negatives_2: 105.0000
# Epoch 11/100
# 643/643 [==============================] - 0s 93us/sample - loss: 0.6398 - acc: 0.6174 - recall_2: 0.5341 - precision_2: 0.6691 - true_negatives_2: 217.0000 - true_positives_2: 180.0000 - false_positives_2: 89.0000 - false_negatives_2: 157.0000
# Epoch 12/100
# 643/643 [==============================] - 0s 94us/sample - loss: 0.6300 - acc: 0.6096 - recall_2: 0.6855 - precision_2: 0.6144 - true_negatives_2: 161.0000 - true_positives_2: 231.0000 - false_positives_2: 145.0000 - false_negatives_2: 106.0000
# Epoch 13/100
# 643/643 [==============================] - 0s 98us/sample - loss: 0.6218 - acc: 0.6236 - recall_2: 0.5905 - precision_2: 0.6568 - true_negatives_2: 202.0000 - true_positives_2: 199.0000 - false_positives_2: 104.0000 - false_negatives_2: 138.0000
# Epoch 14/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6162 - acc: 0.6330 - recall_2: 0.6647 - precision_2: 0.6455 - true_negatives_2: 183.0000 - true_positives_2: 224.0000 - false_positives_2: 123.0000 - false_negatives_2: 113.0000
# Epoch 15/100
# 643/643 [==============================] - 0s 98us/sample - loss: 0.6158 - acc: 0.6252 - recall_2: 0.7092 - precision_2: 0.6257 - true_negatives_2: 163.0000 - true_positives_2: 239.0000 - false_positives_2: 143.0000 - false_negatives_2: 98.0000
# Epoch 16/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.6152 - acc: 0.6143 - recall_2: 0.7389 - precision_2: 0.6088 - true_negatives_2: 146.0000 - true_positives_2: 249.0000 - false_positives_2: 160.0000 - false_negatives_2: 88.0000
# Epoch 17/100
# 643/643 [==============================] - 0s 94us/sample - loss: 0.6205 - acc: 0.6205 - recall_2: 0.6083 - precision_2: 0.6467 - true_negatives_2: 194.0000 - true_positives_2: 205.0000 - false_positives_2: 112.0000 - false_negatives_2: 132.0000
# Epoch 18/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6402 - acc: 0.6143 - recall_2: 0.5875 - precision_2: 0.6450 - true_negatives_2: 197.0000 - true_positives_2: 198.0000 - false_positives_2: 109.0000 - false_negatives_2: 139.0000
# Epoch 19/100
# 643/643 [==============================] - 0s 95us/sample - loss: 0.6290 - acc: 0.6174 - recall_2: 0.6973 - precision_2: 0.6201 - true_negatives_2: 162.0000 - true_positives_2: 235.0000 - false_positives_2: 144.0000 - false_negatives_2: 102.0000
# Epoch 20/100
# 643/643 [==============================] - 0s 95us/sample - loss: 0.6215 - acc: 0.6065 - recall_2: 0.5935 - precision_2: 0.6329 - true_negatives_2: 190.0000 - true_positives_2: 200.0000 - false_positives_2: 116.0000 - false_negatives_2: 137.0000
# Epoch 21/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6242 - acc: 0.6174 - recall_2: 0.6499 - precision_2: 0.6311 - true_negatives_2: 178.0000 - true_positives_2: 219.0000 - false_positives_2: 128.0000 - false_negatives_2: 118.0000
# Epoch 22/100
# 643/643 [==============================] - 0s 94us/sample - loss: 0.6123 - acc: 0.6299 - recall_2: 0.6231 - precision_2: 0.6542 - true_negatives_2: 195.0000 - true_positives_2: 210.0000 - false_positives_2: 111.0000 - false_negatives_2: 127.0000
# Epoch 23/100
# 643/643 [==============================] - 0s 98us/sample - loss: 0.6238 - acc: 0.6314 - recall_2: 0.7982 - precision_2: 0.6142 - true_negatives_2: 137.0000 - true_positives_2: 269.0000 - false_positives_2: 169.0000 - false_negatives_2: 68.0000
# Epoch 24/100
# 643/643 [==============================] - 0s 99us/sample - loss: 0.6210 - acc: 0.6392 - recall_2: 0.7151 - precision_2: 0.6393 - true_negatives_2: 170.0000 - true_positives_2: 241.0000 - false_positives_2: 136.0000 - false_negatives_2: 96.0000
# Epoch 25/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.6245 - acc: 0.6190 - recall_2: 0.6350 - precision_2: 0.6369 - true_negatives_2: 184.0000 - true_positives_2: 214.0000 - false_positives_2: 122.0000 - false_negatives_2: 123.0000
# Epoch 26/100
# 643/643 [==============================] - 0s 95us/sample - loss: 0.6185 - acc: 0.6236 - recall_2: 0.6142 - precision_2: 0.6489 - true_negatives_2: 194.0000 - true_positives_2: 207.0000 - false_positives_2: 112.0000 - false_negatives_2: 130.0000
# Epoch 27/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.6136 - acc: 0.6128 - recall_2: 0.5875 - precision_2: 0.6429 - true_negatives_2: 196.0000 - true_positives_2: 198.0000 - false_positives_2: 110.0000 - false_negatives_2: 139.0000
# Epoch 28/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6170 - acc: 0.6159 - recall_2: 0.6350 - precision_2: 0.6331 - true_negatives_2: 182.0000 - true_positives_2: 214.0000 - false_positives_2: 124.0000 - false_negatives_2: 123.0000
# Epoch 29/100
# 643/643 [==============================] - 0s 95us/sample - loss: 0.6121 - acc: 0.6361 - recall_2: 0.7092 - precision_2: 0.6373 - true_negatives_2: 170.0000 - true_positives_2: 239.0000 - false_positives_2: 136.0000 - false_negatives_2: 98.0000
# Epoch 30/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.6365 - acc: 0.6314 - recall_2: 0.7033 - precision_2: 0.6337 - true_negatives_2: 169.0000 - true_positives_2: 237.0000 - false_positives_2: 137.0000 - false_negatives_2: 100.0000
# Epoch 31/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6259 - acc: 0.6190 - recall_2: 0.6558 - precision_2: 0.6314 - true_negatives_2: 177.0000 - true_positives_2: 221.0000 - false_positives_2: 129.0000 - false_negatives_2: 116.0000
# Epoch 32/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.6119 - acc: 0.6283 - recall_2: 0.6588 - precision_2: 0.6416 - true_negatives_2: 182.0000 - true_positives_2: 222.0000 - false_positives_2: 124.0000 - false_negatives_2: 115.0000
# Epoch 33/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6101 - acc: 0.6159 - recall_2: 0.5697 - precision_2: 0.6531 - true_negatives_2: 204.0000 - true_positives_2: 192.0000 - false_positives_2: 102.0000 - false_negatives_2: 145.0000
# Epoch 34/100
# 643/643 [==============================] - 0s 95us/sample - loss: 0.6181 - acc: 0.6112 - recall_2: 0.6439 - precision_2: 0.6254 - true_negatives_2: 176.0000 - true_positives_2: 217.0000 - false_positives_2: 130.0000 - false_negatives_2: 120.0000
# Epoch 35/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6028 - acc: 0.6283 - recall_2: 0.6291 - precision_2: 0.6503 - true_negatives_2: 192.0000 - true_positives_2: 212.0000 - false_positives_2: 114.0000 - false_negatives_2: 125.0000
# Epoch 36/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6164 - acc: 0.6267 - recall_2: 0.6677 - precision_2: 0.6374 - true_negatives_2: 178.0000 - true_positives_2: 225.0000 - false_positives_2: 128.0000 - false_negatives_2: 112.0000
# Epoch 37/100
# 643/643 [==============================] - 0s 101us/sample - loss: 0.6102 - acc: 0.6252 - recall_2: 0.6944 - precision_2: 0.6290 - true_negatives_2: 168.0000 - true_positives_2: 234.0000 - false_positives_2: 138.0000 - false_negatives_2: 103.0000
# Epoch 38/100
# 643/643 [==============================] - 0s 101us/sample - loss: 0.6216 - acc: 0.6267 - recall_2: 0.6499 - precision_2: 0.6422 - true_negatives_2: 184.0000 - true_positives_2: 219.0000 - false_positives_2: 122.0000 - false_negatives_2: 118.0000
# Epoch 39/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6132 - acc: 0.6267 - recall_2: 0.6320 - precision_2: 0.6474 - true_negatives_2: 190.0000 - true_positives_2: 213.0000 - false_positives_2: 116.0000 - false_negatives_2: 124.0000
# Epoch 40/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.6139 - acc: 0.6159 - recall_2: 0.6320 - precision_2: 0.6339 - true_negatives_2: 183.0000 - true_positives_2: 213.0000 - false_positives_2: 123.0000 - false_negatives_2: 124.0000
# Epoch 41/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6217 - acc: 0.6096 - recall_2: 0.7329 - precision_2: 0.6054 - true_negatives_2: 145.0000 - true_positives_2: 247.0000 - false_positives_2: 161.0000 - false_negatives_2: 90.0000
# Epoch 42/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6177 - acc: 0.6283 - recall_2: 0.6350 - precision_2: 0.6485 - true_negatives_2: 190.0000 - true_positives_2: 214.0000 - false_positives_2: 116.0000 - false_negatives_2: 123.0000
# Epoch 43/100
# 643/643 [==============================] - 0s 95us/sample - loss: 0.6064 - acc: 0.6252 - recall_2: 0.6083 - precision_2: 0.6529 - true_negatives_2: 197.0000 - true_positives_2: 205.0000 - false_positives_2: 109.0000 - false_negatives_2: 132.0000
# Epoch 44/100
# 643/643 [==============================] - 0s 103us/sample - loss: 0.6147 - acc: 0.6190 - recall_2: 0.6113 - precision_2: 0.6438 - true_negatives_2: 192.0000 - true_positives_2: 206.0000 - false_positives_2: 114.0000 - false_negatives_2: 131.0000
# Epoch 45/100
# 643/643 [==============================] - 0s 95us/sample - loss: 0.6107 - acc: 0.6252 - recall_2: 0.6736 - precision_2: 0.6341 - true_negatives_2: 175.0000 - true_positives_2: 227.0000 - false_positives_2: 131.0000 - false_negatives_2: 110.0000
# Epoch 46/100
# 643/643 [==============================] - 0s 95us/sample - loss: 0.6076 - acc: 0.6267 - recall_2: 0.7389 - precision_2: 0.6209 - true_negatives_2: 154.0000 - true_positives_2: 249.0000 - false_positives_2: 152.0000 - false_negatives_2: 88.0000
# Epoch 47/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6379 - acc: 0.6314 - recall_2: 0.6202 - precision_2: 0.6572 - true_negatives_2: 197.0000 - true_positives_2: 209.0000 - false_positives_2: 109.0000 - false_negatives_2: 128.0000
# Epoch 48/100
# 643/643 [==============================] - 0s 94us/sample - loss: 0.6111 - acc: 0.6407 - recall_2: 0.7122 - precision_2: 0.6417 - true_negatives_2: 172.0000 - true_positives_2: 240.0000 - false_positives_2: 134.0000 - false_negatives_2: 97.0000
# Epoch 49/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6114 - acc: 0.6252 - recall_2: 0.6647 - precision_2: 0.6364 - true_negatives_2: 178.0000 - true_positives_2: 224.0000 - false_positives_2: 128.0000 - false_negatives_2: 113.0000
# Epoch 50/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6057 - acc: 0.6423 - recall_2: 0.6617 - precision_2: 0.6578 - true_negatives_2: 190.0000 - true_positives_2: 223.0000 - false_positives_2: 116.0000 - false_negatives_2: 114.0000
# Epoch 51/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.5992 - acc: 0.6392 - recall_2: 0.7033 - precision_2: 0.6423 - true_negatives_2: 174.0000 - true_positives_2: 237.0000 - false_positives_2: 132.0000 - false_negatives_2: 100.0000
# Epoch 52/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.6016 - acc: 0.6236 - recall_2: 0.6499 - precision_2: 0.6385 - true_negatives_2: 182.0000 - true_positives_2: 219.0000 - false_positives_2: 124.0000 - false_negatives_2: 118.0000
# Epoch 53/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.5992 - acc: 0.6314 - recall_2: 0.5875 - precision_2: 0.6689 - true_negatives_2: 208.0000 - true_positives_2: 198.0000 - false_positives_2: 98.0000 - false_negatives_2: 139.0000
# Epoch 54/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.5997 - acc: 0.6112 - recall_2: 0.5371 - precision_2: 0.6582 - true_negatives_2: 212.0000 - true_positives_2: 181.0000 - false_positives_2: 94.0000 - false_negatives_2: 156.0000
# Epoch 55/100
# 643/643 [==============================] - 0s 95us/sample - loss: 0.5950 - acc: 0.6361 - recall_2: 0.7181 - precision_2: 0.6352 - true_negatives_2: 167.0000 - true_positives_2: 242.0000 - false_positives_2: 139.0000 - false_negatives_2: 95.0000
# Epoch 56/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.5968 - acc: 0.6407 - recall_2: 0.6973 - precision_2: 0.6456 - true_negatives_2: 177.0000 - true_positives_2: 235.0000 - false_positives_2: 129.0000 - false_negatives_2: 102.0000
# Epoch 57/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.6056 - acc: 0.6283 - recall_2: 0.6558 - precision_2: 0.6424 - true_negatives_2: 183.0000 - true_positives_2: 221.0000 - false_positives_2: 123.0000 - false_negatives_2: 116.0000
# Epoch 58/100
# 643/643 [==============================] - 0s 95us/sample - loss: 0.5950 - acc: 0.6392 - recall_2: 0.6083 - precision_2: 0.6721 - true_negatives_2: 206.0000 - true_positives_2: 205.0000 - false_positives_2: 100.0000 - false_negatives_2: 132.0000
# Epoch 59/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.6004 - acc: 0.6299 - recall_2: 0.5786 - precision_2: 0.6701 - true_negatives_2: 210.0000 - true_positives_2: 195.0000 - false_positives_2: 96.0000 - false_negatives_2: 142.0000
# Epoch 60/100
# 643/643 [==============================] - 0s 95us/sample - loss: 0.6148 - acc: 0.6345 - recall_2: 0.7418 - precision_2: 0.6281 - true_negatives_2: 158.0000 - true_positives_2: 250.0000 - false_positives_2: 148.0000 - false_negatives_2: 87.0000
# Epoch 61/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.5903 - acc: 0.6330 - recall_2: 0.5846 - precision_2: 0.6724 - true_negatives_2: 210.0000 - true_positives_2: 197.0000 - false_positives_2: 96.0000 - false_negatives_2: 140.0000
# Epoch 62/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.6122 - acc: 0.6283 - recall_2: 0.6855 - precision_2: 0.6346 - true_negatives_2: 173.0000 - true_positives_2: 231.0000 - false_positives_2: 133.0000 - false_negatives_2: 106.0000
# Epoch 63/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6091 - acc: 0.6392 - recall_2: 0.5846 - precision_2: 0.6817 - true_negatives_2: 214.0000 - true_positives_2: 197.0000 - false_positives_2: 92.0000 - false_negatives_2: 140.0000
# Epoch 64/100
# 643/643 [==============================] - 0s 95us/sample - loss: 0.5933 - acc: 0.6485 - recall_2: 0.6617 - precision_2: 0.6657 - true_negatives_2: 194.0000 - true_positives_2: 223.0000 - false_positives_2: 112.0000 - false_negatives_2: 114.0000
# Epoch 65/100
# 643/643 [==============================] - 0s 121us/sample - loss: 0.5841 - acc: 0.6470 - recall_2: 0.6677 - precision_2: 0.6618 - true_negatives_2: 191.0000 - true_positives_2: 225.0000 - false_positives_2: 115.0000 - false_negatives_2: 112.0000
# Epoch 66/100
# 643/643 [==============================] - 0s 94us/sample - loss: 0.6055 - acc: 0.6267 - recall_2: 0.6350 - precision_2: 0.6465 - true_negatives_2: 189.0000 - true_positives_2: 214.0000 - false_positives_2: 117.0000 - false_negatives_2: 123.0000
# Epoch 67/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.5986 - acc: 0.6439 - recall_2: 0.6588 - precision_2: 0.6607 - true_negatives_2: 192.0000 - true_positives_2: 222.0000 - false_positives_2: 114.0000 - false_negatives_2: 115.0000
# Epoch 68/100
# 643/643 [==============================] - 0s 99us/sample - loss: 0.6098 - acc: 0.6190 - recall_2: 0.5875 - precision_2: 0.6513 - true_negatives_2: 200.0000 - true_positives_2: 198.0000 - false_positives_2: 106.0000 - false_negatives_2: 139.0000
# Epoch 69/100
# 643/643 [==============================] - 0s 104us/sample - loss: 0.5917 - acc: 0.6299 - recall_2: 0.5994 - precision_2: 0.6623 - true_negatives_2: 203.0000 - true_positives_2: 202.0000 - false_positives_2: 103.0000 - false_negatives_2: 135.0000
# Epoch 70/100
# 643/643 [==============================] - 0s 99us/sample - loss: 0.5958 - acc: 0.6361 - recall_2: 0.6558 - precision_2: 0.6519 - true_negatives_2: 188.0000 - true_positives_2: 221.0000 - false_positives_2: 118.0000 - false_negatives_2: 116.0000
# Epoch 71/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6078 - acc: 0.6236 - recall_2: 0.6588 - precision_2: 0.6361 - true_negatives_2: 179.0000 - true_positives_2: 222.0000 - false_positives_2: 127.0000 - false_negatives_2: 115.0000
# Epoch 72/100
# 643/643 [==============================] - 0s 95us/sample - loss: 0.6047 - acc: 0.6345 - recall_2: 0.5994 - precision_2: 0.6689 - true_negatives_2: 206.0000 - true_positives_2: 202.0000 - false_positives_2: 100.0000 - false_negatives_2: 135.0000
# Epoch 73/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.5954 - acc: 0.6314 - recall_2: 0.7092 - precision_2: 0.6323 - true_negatives_2: 167.0000 - true_positives_2: 239.0000 - false_positives_2: 139.0000 - false_negatives_2: 98.0000
# Epoch 74/100
# 643/643 [==============================] - 0s 99us/sample - loss: 0.6069 - acc: 0.6174 - recall_2: 0.6914 - precision_2: 0.6213 - true_negatives_2: 164.0000 - true_positives_2: 233.0000 - false_positives_2: 142.0000 - false_negatives_2: 104.0000
# Epoch 75/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.6005 - acc: 0.6205 - recall_2: 0.7478 - precision_2: 0.6131 - true_negatives_2: 147.0000 - true_positives_2: 252.0000 - false_positives_2: 159.0000 - false_negatives_2: 85.0000
# Epoch 76/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.5912 - acc: 0.6423 - recall_2: 0.7685 - precision_2: 0.6302 - true_negatives_2: 154.0000 - true_positives_2: 259.0000 - false_positives_2: 152.0000 - false_negatives_2: 78.0000
# Epoch 77/100
# 643/643 [==============================] - 0s 98us/sample - loss: 0.5888 - acc: 0.6563 - recall_2: 0.7122 - precision_2: 0.6593 - true_negatives_2: 182.0000 - true_positives_2: 240.0000 - false_positives_2: 124.0000 - false_negatives_2: 97.0000
# Epoch 78/100
# 643/643 [==============================] - 0s 94us/sample - loss: 0.5848 - acc: 0.6439 - recall_2: 0.6973 - precision_2: 0.6492 - true_negatives_2: 179.0000 - true_positives_2: 235.0000 - false_positives_2: 127.0000 - false_negatives_2: 102.0000
# Epoch 79/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.5823 - acc: 0.6470 - recall_2: 0.6647 - precision_2: 0.6627 - true_negatives_2: 192.0000 - true_positives_2: 224.0000 - false_positives_2: 114.0000 - false_negatives_2: 113.0000
# Epoch 80/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.5986 - acc: 0.6299 - recall_2: 0.6380 - precision_2: 0.6495 - true_negatives_2: 190.0000 - true_positives_2: 215.0000 - false_positives_2: 116.0000 - false_negatives_2: 122.0000
# Epoch 81/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.5848 - acc: 0.6376 - recall_2: 0.6588 - precision_2: 0.6529 - true_negatives_2: 188.0000 - true_positives_2: 222.0000 - false_positives_2: 118.0000 - false_negatives_2: 115.0000
# Epoch 82/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.5809 - acc: 0.6470 - recall_2: 0.6855 - precision_2: 0.6562 - true_negatives_2: 185.0000 - true_positives_2: 231.0000 - false_positives_2: 121.0000 - false_negatives_2: 106.0000
# Epoch 83/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.5925 - acc: 0.6345 - recall_2: 0.7033 - precision_2: 0.6371 - true_negatives_2: 171.0000 - true_positives_2: 237.0000 - false_positives_2: 135.0000 - false_negatives_2: 100.0000
# Epoch 84/100
# 643/643 [==============================] - 0s 95us/sample - loss: 0.5866 - acc: 0.6283 - recall_2: 0.6558 - precision_2: 0.6424 - true_negatives_2: 183.0000 - true_positives_2: 221.0000 - false_positives_2: 123.0000 - false_negatives_2: 116.0000
# Epoch 85/100
# 643/643 [==============================] - 0s 94us/sample - loss: 0.6057 - acc: 0.6361 - recall_2: 0.7329 - precision_2: 0.6317 - true_negatives_2: 162.0000 - true_positives_2: 247.0000 - false_positives_2: 144.0000 - false_negatives_2: 90.0000
# Epoch 86/100
# 643/643 [==============================] - 0s 102us/sample - loss: 0.6000 - acc: 0.6299 - recall_2: 0.6825 - precision_2: 0.6371 - true_negatives_2: 175.0000 - true_positives_2: 230.0000 - false_positives_2: 131.0000 - false_negatives_2: 107.0000
# Epoch 87/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.5916 - acc: 0.6345 - recall_2: 0.6617 - precision_2: 0.6483 - true_negatives_2: 185.0000 - true_positives_2: 223.0000 - false_positives_2: 121.0000 - false_negatives_2: 114.0000
# Epoch 88/100
# 643/643 [==============================] - 0s 95us/sample - loss: 0.5861 - acc: 0.6314 - recall_2: 0.6083 - precision_2: 0.6613 - true_negatives_2: 201.0000 - true_positives_2: 205.0000 - false_positives_2: 105.0000 - false_negatives_2: 132.0000
# Epoch 89/100
# 643/643 [==============================] - 0s 94us/sample - loss: 0.5859 - acc: 0.6407 - recall_2: 0.7478 - precision_2: 0.6332 - true_negatives_2: 160.0000 - true_positives_2: 252.0000 - false_positives_2: 146.0000 - false_negatives_2: 85.0000
# Epoch 90/100
# 643/643 [==============================] - 0s 98us/sample - loss: 0.5884 - acc: 0.6361 - recall_2: 0.6973 - precision_2: 0.6403 - true_negatives_2: 174.0000 - true_positives_2: 235.0000 - false_positives_2: 132.0000 - false_negatives_2: 102.0000
# Epoch 91/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6080 - acc: 0.6190 - recall_2: 0.7359 - precision_2: 0.6139 - true_negatives_2: 150.0000 - true_positives_2: 248.0000 - false_positives_2: 156.0000 - false_negatives_2: 89.0000
# Epoch 92/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6142 - acc: 0.6283 - recall_2: 0.6944 - precision_2: 0.6324 - true_negatives_2: 170.0000 - true_positives_2: 234.0000 - false_positives_2: 136.0000 - false_negatives_2: 103.0000
# Epoch 93/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6142 - acc: 0.6283 - recall_2: 0.6914 - precision_2: 0.6332 - true_negatives_2: 171.0000 - true_positives_2: 233.0000 - false_positives_2: 135.0000 - false_negatives_2: 104.0000
# Epoch 94/100
# 643/643 [==============================] - 0s 96us/sample - loss: 0.6047 - acc: 0.6252 - recall_2: 0.5104 - precision_2: 0.6935 - true_negatives_2: 230.0000 - true_positives_2: 172.0000 - false_positives_2: 76.0000 - false_negatives_2: 165.0000
# Epoch 95/100
# 643/643 [==============================] - 0s 98us/sample - loss: 0.5992 - acc: 0.6345 - recall_2: 0.5846 - precision_2: 0.6747 - true_negatives_2: 211.0000 - true_positives_2: 197.0000 - false_positives_2: 95.0000 - false_negatives_2: 140.0000
# Epoch 96/100
# 643/643 [==============================] - 0s 97us/sample - loss: 0.5905 - acc: 0.6579 - recall_2: 0.6588 - precision_2: 0.6789 - true_negatives_2: 201.0000 - true_positives_2: 222.0000 - false_positives_2: 105.0000 - false_negatives_2: 115.0000
# Epoch 97/100
# 643/643 [==============================] - 0s 103us/sample - loss: 0.5847 - acc: 0.6423 - recall_2: 0.6499 - precision_2: 0.6616 - true_negatives_2: 194.0000 - true_positives_2: 219.0000 - false_positives_2: 112.0000 - false_negatives_2: 118.0000
# Epoch 98/100
# 643/643 [==============================] - 0s 103us/sample - loss: 0.5793 - acc: 0.6485 - recall_2: 0.6973 - precision_2: 0.6546 - true_negatives_2: 182.0000 - true_positives_2: 235.0000 - false_positives_2: 124.0000 - false_negatives_2: 102.0000
# Epoch 99/100
# 643/643 [==============================] - 0s 101us/sample - loss: 0.5969 - acc: 0.6314 - recall_2: 0.6320 - precision_2: 0.6534 - true_negatives_2: 193.0000 - true_positives_2: 213.0000 - false_positives_2: 113.0000 - false_negatives_2: 124.0000
# Epoch 100/100
# 643/643 [==============================] - 0s 106us/sample - loss: 0.5975 - acc: 0.6376 - recall_2: 0.7359 - precision_2: 0.6327 - true_negatives_2: 162.0000 - true_positives_2: 248.0000 - false_positives_2: 144.0000 - false_negatives_2: 89.0000

# %%
model2.evaluate(URLX_test, URLy_test)
# Out:
# 161/161 [==============================] - 0s 454us/sample - loss: 0.6896 - acc: 0.5528 - recall_2: 1.0000 - precision_2: 0.5528 - true_negatives_2: 0.0000e+00 - true_positives_2: 89.0000 - false_positives_2: 72.0000 - false_negatives_2: 0.0000e+00
# [0.6896391622027995, 0.55279505, 1.0, 0.55279505, 0.0, 89.0, 72.0, 0.0]

# %%
df
# Out:
#       entropy  numDigits  urlLength  numParams  hasHttp  hasHttps  urlIsLive  \
# 0   -4.113173          5         41          0      1.0       0.0        0.0
# 1   -4.055393          5         73          0      1.0       0.0        0.0
# 2   -4.171736          5         55          0      1.0       0.0        0.0
# 3   -4.126561          5         58          0      1.0       0.0        0.0
# 4   -4.096221          5         73          0      1.0       0.0        0.0
# ..        ...        ...        ...        ...      ...       ...        ...
# 799 -4.469354          6         59          0      1.0       0.0        0.0
# 800 -4.469354          6         59          0      1.0       0.0        0.0
# 801 -4.503252          6         59          0      1.0       0.0        0.0
# 802 -4.537150          6         59          0      1.0       0.0        0.0
# 803 -4.371087          6         37          0      0.0       1.0        0.0
#
#      bodyLength  numTitles  numImages  ...  specialChars  ext  dsr  dse  \
# 0          4915          5          0  ...          1185    4    0    0
# 1          5027          5          0  ...          1216    4    0    0
# 2          4963          5          0  ...          1196    4    0    0
# 3          4975          5          0  ...          1209    4    0    0
# 4          5033          5          0  ...          1214    4    0    0
# ..          ...        ...        ...  ...           ...  ...  ...  ...
# 799        2648          2          3  ...           598  101    0    0
# 800        1919          2          3  ...           454  100    0    0
# 801        2612          2          3  ...           573   99    0    0
# 802        2691          2          3  ...           603   98    0    0
# 803       21966         17         31  ...          5149    4    0    0
#
#          sscr       sbr      bscr  num_%20  num_@  has_ip
# 0    2.719831  0.655748  0.241099        0      0       0
# 1    2.742599  0.663418  0.241894        0      0       0
# 2    2.734950  0.659077  0.240983        0      0       0
# 3    2.715467  0.659899  0.243015        0      0       0
# 4    2.747117  0.662627  0.241208        0      0       0
# ..        ...       ...       ...      ...    ...     ...
# 799  1.394649  0.314955  0.225831        0      0       0
# 800  1.837004  0.434601  0.236582        0      0       0
# 801  1.455497  0.319296  0.219372        0      0       0
# 802  1.383085  0.309922  0.224080        0      0       0
# 803  2.146242  0.503096  0.234408        0      0       0
#
# [804 rows x 22 columns]

# %% [markdown]
# # Combined Predictions

# %%
CNNRNNaccuracy = {}

CNNRNNaccuracy['model'] = model.evaluate(
    CNNRNNX_test, CNNRNNy_test, verbose=0)

CNNRNNaccuracy = CNNRNNaccuracy['model'][1]

# %%
URLaccuracy = {}

URLaccuracy['model'] = model2.evaluate(
    URLX_test, URLy_test, verbose=0)

URLaccuracy = URLaccuracy['model'][1]

# %%
# CNNRNNweight = CNNRNNaccuracy / (CNNRNNaccuracy + URLaccuracy)
# URLweight = URLaccuracy / (CNNRNNaccuracy + URLaccuracy)

CNNRNNweight = 0.6
URLweight = 0.4

print(CNNRNNweight, URLweight)
# Out:
# 0.6 0.4

# %%
CNNRNNpredictions = model.predict(CNNRNNX_test)

# %%
URLpredictions = model2.predict(URLX_test)

# %%
CNNRNNpredictions[0]*0.6
# Out:
# array([0.39244664], dtype=float32)

# %%
URLpredictions[0]*0.4
# Out:
# array([0.38452467], dtype=float32)

# %%
newCNNRNNpredictions = []

for x in range(len(CNNRNNpredictions)):
  newCNNRNNpredictions.append([CNNRNNpredictions[x]*CNNRNNweight])

# %%
newURLpredictions = []

for x in range(len(URLpredictions)):
  newURLpredictions.append([URLpredictions[x]*URLweight])

# %%
combinedResultArray = []
for x in range(len(newCNNRNNpredictions)):
  combinedResultArray.append([newCNNRNNpredictions[x][0]+newURLpredictions[x]])

# %%
for x in range(len(combinedResultArray)):
  if combinedResultArray[x] >= [0.5]:
    combinedResultArray[x] = [1]
  else:
    combinedResultArray[x] = [0]

# %%
len(URLy_test)
# Out:
# 1825

# %%
# predict as true
combinedTP = 0
# predict as false
combinedTN = 0
# incorrectly predict as true
combinedFP = 0
# incorrectly predict as false
combinedFN = 0

for x in range(len(combinedResultArray)):
    if combinedResultArray[x] == [1] and URLy_test[x] == 1: # with URLy_test having the correct labels for the testing set which the combined result mechanism uses
        combinedTP += 1
    elif combinedResultArray[x] == [0] and URLy_test[x] == 0:
        combinedTN += 1
    elif combinedResultArray[x] == [1] and URLy_test[x] == 0:
        combinedFP += 1
    elif combinedResultArray[x] == [0] and URLy_test[x] == 1:
        combinedFN += 1
        
combinedTP, combinedTN, combinedFP, combinedFN
# Out:
# (249, 115, 26, 16)

# %%
combinedAcc = (combinedTP + combinedTN) / (combinedTP + combinedTN + combinedFP + combinedFN)
combinedRecall = combinedTP / (combinedTP + combinedFN)
combinedPrecision = combinedTP / (combinedTP + combinedFP)

print("Accuracy: " + str(combinedAcc) + "\nRecall: " + str(combinedRecall) + "\nPrecision: " + str(combinedPrecision) + "\nTN: " + str(combinedTN) + "\nTP: " + 
      str(combinedTP) + "\nFP: " + str(combinedFP) + "\nFN: " + str(combinedFN))
# Out:
# Accuracy: 0.896551724137931
# Recall: 0.939622641509434
# Precision: 0.9054545454545454
# TN: 115
# TP: 249
# FP: 26
# FN: 16

# %% [markdown]
# # Inputting Singular URLs
